# %%
# testing the other clalculator outputs
import sys
import os
import networkx as nx
import matplotlib.pyplot as plt

import traceback
sys.path.append(os.getcwd())
from Models.Graph_Classifier import GraphClassifier
from Calculators.GEDLIB_Caclulator import GEDLIB_Calculator
from Calculators.Dummy_Calculator import Dummy_Calculator
from Dataset import Dataset

# %%
def visualize_graph(graph: nx.Graph, node_labels_type: str = None, edge_labels_type: str = None,header:str="Graph Visualization"):
    """
    Visualisiert einen NetworkX-Graphen mit optionalen Knoten- und Kantenbeschriftungen.
    """
    pos = nx.spring_layout(graph)
    if node_labels_type is not None:
        node_labels = nx.get_node_attributes(graph, node_labels_type)

    # Erstelle ein Dictionary für die Kantenbeschriftungen (Gewichte)
    if edge_labels_type is not None:
        edge_labels = nx.get_edge_attributes(graph, edge_labels_type)

    # Lege die Position der Knoten fest (hier zufällig, kann auch manuell erfolgen)
    pos = nx.spring_layout(graph)

    # Zeichne die Knoten
    nx.draw_networkx_nodes(graph, pos, node_color='lightblue', node_size=700)

    # Zeichne die Kanten
    nx.draw_networkx_edges(graph, pos)

    # Zeichne die Knotenbeschriftungen
    nx.draw_networkx_labels(graph, pos, labels=node_labels, font_size=12, font_color='black')

    # Zeichne die Kantenbeschriftungen
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels, font_size=10, font_color='red')

    # Zeige den Plot an
    plt.title(header)
    plt.axis('off')  # Achsen ausschalten
    plt.show()

# %%
def createNxGraph() :
    G = nx.Graph()
    G.add_node("C1", label = "C1", attr= "0.5")
    G.add_node("02", label = "02", attr= "0.5")
    # G.add_edge("C1", "02", label = "1", attr= "0.5")
    G.add_node("N3", label = "N3", attr= "0.5")
    G.add_node("C4", label = "C4", attr= "0.5")
    G.add_node("H5", label = "H5", attr= "0.5")
    G.add_node("H6", label = "H6", attr= "0.5")
    # G.add_edge("N3", "C4", label = "1", attr= "0.5")
    G.add_edge("C1", "C4", label = "a", attr= "0.5")
    G.add_edge("C4", "02", label = "a", attr= "0.5")
    G.add_edge("C4", "N3", label = "a", attr= "0.5")
    G.add_edge("C1", "H5", label = "a", attr= "2")
    return G
def createNxGraph2() :
    G = nx.Graph()
    G.add_node("C1", label = "lC1", attr= "0.5")
    G.add_node("O2", label = "lO2", attr= "0.5")
    G.add_edge("C1", "O2", label = "b", attr= "0.5")
    G.add_node("C4", label = "lC4", attr= "0.5")
    G.add_node("N3", label = "lN3", attr= "0.5")   
    G.add_edge("N3", "C4", label = "b", attr= "0.5")
    G.add_edge("N3", "O2", label = "b", attr= "0.5")
    return G
def createNxGraph3():
    G = nx.Graph()
    G.add_node("C1", label = "lC1", attr= "0.5")
    G.add_node("O2", label = "lO2", attr= "0.5")
    G.add_edge("C1", "O2", label = "b", attr= "0.5")
    G.add_node("C4", label = "lC4", attr= "0.5")
    G.add_node("N3", label = "lN3", attr= "0.5")  
    G.add_node("H5", label = "lH5", attr= "0.5")
    G.add_node("H6", label = "lH6", attr= "0.5") 
    G.add_edge("N3", "C4", label = "b", attr= "0.5")
    G.add_edge("N3", "O2", label = "b", attr= "0.5")

    G.add_edge("C4", "H5", label = "b", attr= "0.5")
    G.add_edge("H5", "H6", label = "b", attr= "0.5")
    return G
def createNxGraph4A():
    G = nx.Graph()
    G.add_node(1, label = "C1", attr= "0.5")
    G.add_node(2, label = "O2", attr= "0.5")
    G.add_node(3, label = "A3", attr= "0.5")
    G.add_node(4, label = "C4", attr= "0.5")
    G.add_edge(1, 2, label = "b", attr= "0.5")
    G.add_edge(2, 3, label = "b", attr= "0.5")
    G.add_edge(3, 1, label = "b", attr= "0.5")
    G.add_edge(2, 4, label = "b", attr= "0.5")
    G.add_edge(4, 3, label = "b", attr= "0.5")
    return G
def createNxGraph4A2():
    G = nx.Graph()
    G.add_node(1, label = "C1", attr= "0.5")
    G.add_node(2, label = "O2", attr= "0.5")
    G.add_node(3, label = "A3", attr= "0.5")
    G.add_node(4, label = "C4", attr= "0.5")
    G.add_edge(1, 2, label = "b", attr= "0.5")
    G.add_edge(2, 3, label = "b", attr= "0.5")
    G.add_edge(3, 1, label = "b", attr= "0.5")
    G.add_edge(2, 4, label = "b", attr= "0.5")
    G.add_edge(4, 3, label = "b", attr= "0.5")
    return G
def createNxGraph4B():
    G = nx.Graph()
    G.add_node(1, label = "C1", attr= "0.5")
    G.add_node(2, label = "O2", attr= "0.5")
    G.add_node(3, label = "A3", attr= "0.5")
    G.add_node(4, label = "C4", attr= "0.5")
    G.add_node(5, label = "C5", attr= "0.5")
    G.add_edge(1, 2, label = "b", attr= "0.5")
    G.add_edge(2, 3, label = "b", attr= "0.5")
    G.add_edge(3, 1, label = "b", attr= "0.5")
    G.add_edge(3, 4, label = "b", attr= "0.5")
    G.add_edge(4, 5, label = "b", attr= "0.5")
    G.add_edge(5, 3, label = "b", attr= "0.5")
    G.add_edge(2, 4, label = "b", attr= "0.5")
    return G

# %%
DATASET= Dataset(name="MUTAG", source="TUD", domain="Bioinformatics", ged_calculator=None, use_node_labels="label", use_edge_labels="weight",load_now=False)
DATASET.load()
a1=98
a2=175
d1,t1=DATASET.get_graph_pair(a1)
d2,t2=DATASET.get_graph_pair(a2)
# Out:
# Loading MUTAG into NetworkX from Datasets/TUD/MUTAG...
# Loaded 7442 edges.
# Loaded 3371 node-to-graph mappings.
# Loaded 188 graph labels.
# Loaded node labels for 3371 nodes.
# Loaded edge labels for 7442 edges.
# Converting graphs to NetworkX format: 100%|██████████| 188/188 [00:00<00:00, 2184291.28it/s]
# Converted 188 graphs to NetworkX format.
# Now setting up the Calculator

# %%
g1= createNxGraph4B()
g1=d1
visualize_graph(g1, node_labels_type="label", edge_labels_type="label",header=f"Graph {a1},class={t1}")
g2 = createNxGraph4A()
g2=d2
visualize_graph(g2, node_labels_type="label", edge_labels_type="label",header=f"Graph {a2},class={t2}")

# %%
from Calculators.Product_GRaphs import build_restricted_product_graph

DATASET= None
ged_calculator = "GEDLIB_Calculator"
DATASET= Dataset(name="MUTAG", source="TUD", domain="Bioinformatics", ged_calculator=ged_calculator, use_node_labels="label", use_edge_labels="label",load_now=False)
DATASET.load()
ged_calculator=DATASET.get_calculator()
print(ged_calculator.get_node_map(a1,a2))
pg=build_restricted_product_graph(g1,g2,node_matches=ged_calculator.get_node_map(a1,a2))
adj_matrix=nx.to_numpy_array(pg)
display(adj_matrix)
display(nx.adjacency_matrix(pg).todense())
visualize_graph(pg, node_labels_type="label", edge_labels_type="label",header="Product Graph")
# Out:
# Loading MUTAG into NetworkX from Datasets/TUD/MUTAG...
# Loaded 7442 edges.
# Loaded 3371 node-to-graph mappings.
# Loaded 188 graph labels.
# Loaded node labels for 3371 nodes.
# Loaded edge labels for 7442 edges.
# Converting graphs to NetworkX format: 100%|██████████| 188/188 [00:00<00:00, 2339849.12it/s]
# Converted 188 graphs to NetworkX format.
# Now setting up the Calculator
# [(0, 2), (1, 3), (2, 4), (3, 18446744073709551614), (4, 18446744073709551614), (5, 11), (6, 18446744073709551614), (7, 5), (8, 0), (9, 1), (10, 10), (11, 9), (12, 6), (13, 7), (14, 8)]

# %%
for node in g1.nodes(data=True):
    # add 5 to each node id
    g1 = nx.relabel_nodes(g1, {node[0]: node[0] + 20})

# now also reconfigure the edges accordingly
# for edge in g1.edges(data=True):
#     u, v = edge[0], edge[1]
#     if g1.has_edge(u, v):
#         g1[u][v] = edge[2]

# %%
dataset= [g2, g1]
calculator = GEDLIB_Calculator(GED_calc_method="BIPARTITE", GED_edit_cost="CONSTANT",need_node_map=True)
calculator.add_graphs(dataset)
calculator.activate()
calculator.run_method(0, 1)
calculator.run_method(1, 0)
# Out:
# Initialized Dummy_Calculator with GED_edit_cost=CONSTANT and GED_calc_method=BIPARTITE

# %%
display(calculator.get_lower_bound(0, 1))
display(calculator.get_upper_bound(0, 1))
# Out:
# 0.0
# 37.0

# %%
display(calculator.get_forward_map(0,1))
# Out:
# [18, 17, 8, 3, 4, 15, 6, 9, 0, 1, 2]

# %%
display(calculator.get_backward_map(0,1))
# Out:
# [8,
#  9,
#  10,
#  3,
#  4,
#  18446744073709551614,
#  6,
#  18446744073709551614,
#  2,
#  7,
#  18446744073709551614,
#  18446744073709551614,
#  18446744073709551614,
#  18446744073709551614,
#  18446744073709551614,
#  5,
#  18446744073709551614,
#  1,
#  0,
#  18446744073709551614]

# %%
display(calculator.get_all_map(0,1))
# Out:
# [[18, 17, 8, 3, 4, 15, 6, 9, 0, 1, 2],
#  [8,
#   9,
#   10,
#   3,
#   4,
#   18446744073709551614,
#   6,
#   18446744073709551614,
#   2,
#   7,
#   18446744073709551614,
#   18446744073709551614,
#   18446744073709551614,
#   18446744073709551614,
#   18446744073709551614,
#   5,
#   18446744073709551614,
#   1,
#   0,
#   18446744073709551614]]

# %%
node_map=calculator.get_node_map(0,1)
display(node_map)
# Out:
# [(8, 0),
#  (9, 1),
#  (10, 2),
#  (3, 3),
#  (4, 4),
#  (18446744073709551614, 5),
#  (6, 6),
#  (18446744073709551614, 7),
#  (5, 8),
#  (7, 9),
#  (18446744073709551614, 10),
#  (18446744073709551614, 11),
#  (18446744073709551614, 12),
#  (18446744073709551614, 13),
#  (2, 14),
#  (0, 15),
#  (1, 16),
#  (18446744073709551614, 17),
#  (18446744073709551614, 18),
#  (18446744073709551614, 19)]

# %%
# display(calculator.get_assignment_matrix(0,1))

# %%
# display(calculator.get_node_image(0,1,0))
# display(calculator.get_node_image(0,1,1))
# display(calculator.get_node_image(0,1,2))
# display(calculator.get_node_image(0,1,3))
# display(calculator.get_node_image(0,1,4))
# display(calculator.get_node_image(0,1,5))

# %%
display(g1.edges)
# Out:
# EdgeView([(1927, 1928), (1927, 1920), (1927, 1915), (1927, 1929), (1928, 1929), (1929, 1910), (1929, 1918), (1910, 1911), (1911, 1912), (1912, 1913), (1912, 1917), (1913, 1914), (1914, 1915), (1915, 1916), (1916, 1917), (1916, 1922), (1917, 1918), (1918, 1919), (1919, 1920), (1919, 1921), (1921, 1922), (1921, 1926), (1922, 1923), (1923, 1924), (1924, 1925), (1925, 1926)])

# %%
display(g2.edges)
# Out:
# EdgeView([(3003, 3004), (3004, 3005), (3005, 3006), (3005, 3010), (3006, 3007), (3007, 3008), (3008, 3009), (3008, 3011), (3009, 3010), (3011, 3012), (3011, 3013)])

# %%
from Calculators.Product_GRaphs import build_restricted_product_graph,limited_length_approx_random_walk_similarity,infinte_length_random_walk_similarity
prod_graph = build_restricted_product_graph(g1, g2, node_map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 from Calculators.Product_GRaphs import build_restricted_product_graph,limited_length_approx_random_walk_similarity,infinte_length_random_walk_similarity
# ----> 2 prod_graph = build_restricted_product_graph(g1, g2, node_map)
#
# File ~/Thesis-Code/The-GED-classifier-bakeoff/Calculators/Product_GRaphs.py:25, in build_restricted_product_graph(g1, g2, node_matches)
#      23         node1_id = node1 + lowest_node_id_g1
#      24         node2_id = node2 + lowest_node_id_g2
# ---> 25         label = (g1.nodes[node1_id].get('label', None), g2.nodes[node2_id].get('label', None))
#      26         restricted_graph.add_node((node1_id, node2_id))
#      27 # rather inefficient O(n^2) approach,
#      28 # possible better to iterate over the edges of g1, and check if the corresponding edge exists in g2
# ...

# %%
visualize_graph(prod_graph, node_labels_type="label", edge_labels_type="label",header="Product Graph")

# %%
random_walk_similarity = limited_length_approx_random_walk_similarity(prod_graph, llamda=0.1, max_length=10)
display(random_walk_similarity)

# %%
random_walk_similarity2=infinte_length_random_walk_similarity(prod_graph, llamda=0.1)
display(random_walk_similarity2)
