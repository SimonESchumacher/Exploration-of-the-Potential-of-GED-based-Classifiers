# %%
from Calculators.GED_Calculator import exact_GED_Calculator, build_exact_ged_calculator
from Dataset import Dataset

# %%
from Experiment import experiment
import sys
import os
import traceback

from Models.SVC.GED.hybrid_prototype_selector import HybridPrototype_GED_SVC
sys.path.append(os.getcwd())
from Models.SVC.GED.RandomWalk_edit import Random_Walk_edit_accelerated, Random_walk_edit_SVC
from Models.SVC.WeisfeilerLehman_SVC import WeisfeilerLehman_SVC
from Models.Graph_Classifier import GraphClassifier
from Models.SVC.Baseline_SVC import VertexHistogram_SVC,EdgeHistogram_SVC, CombinedHistogram_SVC, NX_Histogram_SVC
from Models.Blind_Classifier import Blind_Classifier
from Models.Random_Classifer import Random_Classifier
from Models.KNN_Classifer import KNN
from Models.SVC.GED.Trivial_GED_SVC import Trivial_GED_SVC
from Custom_Kernels.GEDLIB_kernel import GEDKernel
from Calculators.Dummy_Calculator import Dummy_Calculator
from Calculators.Base_Calculator import Base_Calculator
from Calculators.GEDLIB_Caclulator import GEDLIB_Calculator
from Models.SVC.GED.GED_Diffu_SVC import DIFFUSION_GED_SVC
from Models.SVC.GED.Zero_GED_SVC import ZERO_GED_SVC
from Models.SVC.GED.simiple_prototype_GED_SVC import Simple_Prototype_GED_SVC
from Models.SVC.Base_GED_SVC import Base_GED_SVC, set_global_ged_calculator
from Models.KNN.GEDLIB_KNN import GED_KNN, set_global_ged_calculator_KNN
from Models.KNN.feature_KNN import Feature_KNN
import pandas as pd
from io_Manager import IO_Manager

# %%
def convert_Dataset_to_exact_GED_format(dataset:Dataset):
    dataset_name = dataset.get_name()
    filepath = f"Datasets/ged/{dataset_name}/"
    os.makedirs(os.path.dirname(filepath) or '.', exist_ok=True)

    for graph_index, G in enumerate(dataset.get_graphs()):
        graph_path = os.path.join(filepath, f"g_{graph_index}.txt")
        output_lines = []
        # 1. Create a mapping from NetworkX's original node IDs to new sequential 0-based IDs
        original_nodes = list(G.nodes())
        node_id_map = {original_id: new_id for new_id, original_id in enumerate(original_nodes)}
        
        num_nodes = G.number_of_nodes()
        
        # Determine the arbitrary strings for the 't' line
        t_val1 = G.graph.get("Name", f"#{graph_index}")
        t_val2 = num_nodes
        # 2. Generate the 't' line
        output_lines.append(f"t {t_val1} {t_val2}")
        
        # 3. Generate 'v' lines
        for original_id, new_id in node_id_map.items():
            # Safely retrieve the node label attribute
            label = G.nodes[original_id].get(dataset.Node_label_name, 0)
            output_lines.append(f"v {new_id} {label}")
            
        # 4. Generate 'e' lines
        for u_orig, v_orig, data in G.edges(data=True):
            # Get the new sequential IDs
            u_new = node_id_map[u_orig]
            v_new = node_id_map[v_orig]
            
            # Safely retrieve the edge label attribute
            label = data.get(dataset.Edge_label_name, 0)
            
            # The format expects 'e [vertex_id1] [vertex_id2] [edge_label]'
            output_lines.append(f"e {u_new} {v_new} {label}")
        # 5. Write to file
        try:
            # Ensure the directory exists
            with open(graph_path, 'w') as f:
                f.write('\n'.join(output_lines) + '\n') # Add final newline for file hygiene
        except IOError as e:
            print(f"\nError writing to file '{graph_path}': {e}")

# %%
DATASET_NAME="MUTAG"
PRELOAD_CALCULATORS=True
USE_NODE_LABELS="labels"
USE_EDGE_LABELS="labels"
GED_BOUND="IPFP"  # "UpperBound-Distance", "Mean-Distance", "LowerBound-Distance"
def get_classifier(ged_calculator):
    set_global_ged_calculator_KNN(ged_calculator)

    # return ZERO_GED_SVC(calculator_id=ged_calculator.get_identifier_name(), ged_bound=GED_BOUND, C=1.0,kernel_type="precomputed", selection_split="classwise",prototype_size=7, aggregation_method="sum",dataset_name=DATASET.name,selection_method="k-CPS")
    # return Random_walk_edit_SVC(ged_calculator=ged_calculator, ged_bound=GED_BOUND, decay_lambda=0.1, max_walk_length=-1, C=1.0,kernel_type="precomputed", class_weight='balanced')
    # random_walk_calculator = RandomWalkCalculator(ged_calculator=ged_calculator, llambda_samples=[0.005,0.01,0.03,0.05,0.1,0.2,0.45,0.89], dataset=DATASET,ged_method=GED_BOUND)
    # random_walk_calculator = build_Randomwalk_GED_calculator(ged_calculator=ged_calculator)
    # random_walk_calculator_id = random_walk_calculator.get_identifier_name()

    # return Random_Walk_edit_accelerated(calculator_id=ged_calculator.get_identifier_name(), ged_bound=GED_BOUND, decay_lambda=0.1, max_walk_length=-1, C=1.0,kernel_type="precomputed", class_weight='balanced',random_walk_calculator_id=random_walk_calculator_id)
    return Trivial_GED_SVC(calculator_id=ged_calculator.get_identifier_name(),ged_bound=GED_BOUND, C=1.0,kernel_type="precomputed", class_weight='balanced',similarity_function='k4')
    # return  Simple_Prototype_GED_SVC(calculator_id=ged_calculator.get_identifier_name(), ged_bound=GED_BOUND, C=1.0,kernel_type="poly", class_weight='balanced',prototype_size=8, selection_method="k-CPS", selection_split="all",dataset_name=DATASET_NAME)
    # return DIFFUSION_GED_SVC(C=1.0, llambda=1.0, calculator_id=ged_calculator.get_identifier_name(), ged_bound=GED_BOUND, diffusion_function="exp_diff_kernel", class_weight='balanced', t_iterations=5)
    # return CombinedHistogram_SVC(kernel_type='precomputed')
    # return Feature_KNN(vector_feature_list=["VertexHistogram","density","Prototype-Distance"], dataset_name=DATASET.name, prototype_size=5, selection_split="all", selection_method="TPS", metric="minkowski", calculator_id=ged_calculator.get_identifier_name(), ged_bound=GED_BOUND, n_neighbors=5, weights='uniform', algorithm='auto')
def get_Dataset(dataset_name: str, ged_calculator):
    DATASET= Dataset(name=dataset_name, source="TUD", domain="Bioinformatics", ged_calculator=None, use_node_labels=USE_NODE_LABELS, use_edge_labels=USE_EDGE_LABELS,load_now=False)
    DATASET.load()
    convert_Dataset_to_exact_GED_format(DATASET)
    ged_calculator = build_exact_ged_calculator(DATASET.get_graphs(),dataset_name=DATASET_NAME, n_jobs=8)
    return DATASET, ged_calculator
DATASET, ged_calculator = get_Dataset(DATASET_NAME, None)
set_global_ged_calculator(ged_calculator)
# Out:
# Loading MUTAG into NetworkX from Datasets/TUD/MUTAG...
# Loaded 7442 edges.
# Loaded 3371 node-to-graph mappings.
# Loaded 188 graph labels.
# Loaded node labels for 3371 nodes.
# Loaded edge labels for 7442 edges.
# Converting graphs to NetworkX format: 100%|██████████| 188/188 [00:00<00:00, 1890957.20it/s]
# Converted 188 graphs to NetworkX format.
# Now setting up the Calculator
# Starting calculation of exact GED distance matrix with 8 parallel jobs...
# Timeout expired when computing GED between graph 0 and graph 62.
# Timeout expired when computing GED between graph 3 and graph 22.
# Timeout expired when computing GED between graph 3 and graph 5.
# Timeout expired when computing GED between graph 3 and graph 26.
# Timeout expired when computing GED between graph 3 and graph 31.
# Timeout expired when computing GED between graph 3 and graph 46.
# Timeout expired when computing GED between graph 3 and graph 45.
# Timeout expired when computing GED between graph 3 and graph 58.
# Timeout expired when computing GED between graph 3 and graph 32.
# Timeout expired when computing GED between graph 3 and graph 62.
# Timeout expired when computing GED between graph 3 and graph 57.
# Timeout expired when computing GED between graph 3 and graph 29.
# Timeout expired when computing GED between graph 3 and graph 67.
# Timeout expired when computing GED between graph 3 and graph 84.
# Timeout expired when computing GED between graph 3 and graph 90.
# Timeout expired when computing GED between graph 3 and graph 95.
# Timeout expired when computing GED between graph 3 and graph 101.
# Timeout expired when computing GED between graph 3 and graph 117.
# Timeout expired when computing GED between graph 3 and graph 85.
# Timeout expired when computing GED between graph 3 and graph 133.
# Timeout expired when computing GED between graph 3 and graph 109.
# Timeout expired when computing GED between graph 3 and graph 161.
# Timeout expired when computing GED between graph 3 and graph 162.
# Timeout expired when computing GED between graph 3 and graph 170.
# Timeout expired when computing GED between graph 5 and graph 6.
# Timeout expired when computing GED between graph 5 and graph 9.
# Timeout expired when computing GED between graph 5 and graph 17.
# Timeout expired when computing GED between graph 5 and graph 21.
# Timeout expired when computing GED between graph 5 and graph 29.
# Timeout expired when computing GED between graph 5 and graph 26.
# Timeout expired when computing GED between graph 5 and graph 34.
# Timeout expired when computing GED between graph 5 and graph 15.
# Timeout expired when computing GED between graph 5 and graph 7.
# Timeout expired when computing GED between graph 5 and graph 22.
# Timeout expired when computing GED between graph 5 and graph 30.
# Timeout expired when computing GED between graph 5 and graph 19.
# Timeout expired when computing GED between graph 5 and graph 27.
# Timeout expired when computing GED between graph 5 and graph 12.
# Timeout expired when computing GED between graph 5 and graph 42.
# Timeout expired when computing GED between graph 5 and graph 40.
# Timeout expired when computing GED between graph 5 and graph 50.
# Timeout expired when computing GED between graph 5 and graph 23.
# Timeout expired when computing GED between graph 5 and graph 31.
# Timeout expired when computing GED between graph 5 and graph 28.
# Timeout expired when computing GED between graph 5 and graph 57.
# Timeout expired when computing GED between graph 5 and graph 73.
# Timeout expired when computing GED between graph 5 and graph 51.
# Timeout expired when computing GED between graph 5 and graph 24.
# Timeout expired when computing GED between graph 5 and graph 32.
# Timeout expired when computing GED between graph 5 and graph 81.
# Timeout expired when computing GED between graph 5 and graph 45.
# Timeout expired when computing GED between graph 5 and graph 66.
# Timeout expired when computing GED between graph 5 and graph 58.
# Timeout expired when computing GED between graph 5 and graph 74.
# Timeout expired when computing GED between graph 5 and graph 52.
# Timeout expired when computing GED between graph 5 and graph 89.
# Timeout expired when computing GED between graph 5 and graph 82.
# Timeout expired when computing GED between graph 5 and graph 46.
# Timeout expired when computing GED between graph 5 and graph 67.
# Timeout expired when computing GED between graph 5 and graph 100.
# Timeout expired when computing GED between graph 5 and graph 59.
# Timeout expired when computing GED between graph 5 and graph 53.
# Timeout expired when computing GED between graph 5 and graph 90.
# Timeout expired when computing GED between graph 5 and graph 84.
# Timeout expired when computing GED between graph 5 and graph 68.
# Timeout expired when computing GED between graph 5 and graph 101.
# Timeout expired when computing GED between graph 5 and graph 60.
# Timeout expired when computing GED between graph 5 and graph 48.
# Timeout expired when computing GED between graph 5 and graph 91.
# Timeout expired when computing GED between graph 5 and graph 85.
# Timeout expired when computing GED between graph 5 and graph 56.
# Timeout expired when computing GED between graph 5 and graph 105.
# Timeout expired when computing GED between graph 5 and graph 79.
# Timeout expired when computing GED between graph 5 and graph 62.
# Timeout expired when computing GED between graph 5 and graph 70.
# Timeout expired when computing GED between graph 5 and graph 92.
# Timeout expired when computing GED between graph 5 and graph 103.
# Timeout expired when computing GED between graph 5 and graph 113.
# Timeout expired when computing GED between graph 5 and graph 106.
# Timeout expired when computing GED between graph 5 and graph 121.
# Timeout expired when computing GED between graph 5 and graph 63.
# Timeout expired when computing GED between graph 5 and graph 71.
# Timeout expired when computing GED between graph 5 and graph 114.
# Timeout expired when computing GED between graph 5 and graph 94.
# Timeout expired when computing GED between graph 5 and graph 107.
# Timeout expired when computing GED between graph 5 and graph 122.
# Timeout expired when computing GED between graph 5 and graph 132.
# Timeout expired when computing GED between graph 5 and graph 72.
# Timeout expired when computing GED between graph 5 and graph 139.
# Timeout expired when computing GED between graph 5 and graph 145.
# Timeout expired when computing GED between graph 5 and graph 116.
# Timeout expired when computing GED between graph 5 and graph 108.
# Timeout expired when computing GED between graph 5 and graph 96.
# Timeout expired when computing GED between graph 5 and graph 133.
# Timeout expired when computing GED between graph 5 and graph 141.
# Timeout expired when computing GED between graph 5 and graph 125.
# Timeout expired when computing GED between graph 5 and graph 155.
# Timeout expired when computing GED between graph 5 and graph 117.
# Timeout expired when computing GED between graph 5 and graph 109.
# Timeout expired when computing GED between graph 5 and graph 161.
# Timeout expired when computing GED between graph 5 and graph 136.
# Timeout expired when computing GED between graph 5 and graph 162.
# Timeout expired when computing GED between graph 5 and graph 126.
# Timeout expired when computing GED between graph 5 and graph 118.
# Timeout expired when computing GED between graph 5 and graph 157.
# Timeout expired when computing GED between graph 5 and graph 164.
# Timeout expired when computing GED between graph 5 and graph 149.
# Timeout expired when computing GED between graph 5 and graph 127.
# Timeout expired when computing GED between graph 5 and graph 170.
# Timeout expired when computing GED between graph 5 and graph 172.
# Timeout expired when computing GED between graph 5 and graph 159.
# Timeout expired when computing GED between graph 5 and graph 173.
# Timeout expired when computing GED between graph 5 and graph 151.
# Timeout expired when computing GED between graph 5 and graph 120.
# Timeout expired when computing GED between graph 5 and graph 174.
# Timeout expired when computing GED between graph 5 and graph 175.
# Timeout expired when computing GED between graph 5 and graph 176.
# Timeout expired when computing GED between graph 5 and graph 160.
# Timeout expired when computing GED between graph 5 and graph 178.
# Timeout expired when computing GED between graph 5 and graph 152.
# Timeout expired when computing GED between graph 5 and graph 179.
# Timeout expired when computing GED between graph 5 and graph 183.
# Timeout expired when computing GED between graph 5 and graph 185.
# Timeout expired when computing GED between graph 5 and graph 186.
# Timeout expired when computing GED between graph 6 and graph 62.
# Timeout expired when computing GED between graph 6 and graph 178.
# Timeout expired when computing GED between graph 7 and graph 22.
# Timeout expired when computing GED between graph 7 and graph 29.
# Timeout expired when computing GED between graph 7 and graph 45.
# Timeout expired when computing GED between graph 7 and graph 53.
# Timeout expired when computing GED between graph 7 and graph 26.
# Timeout expired when computing GED between graph 7 and graph 57.
# Timeout expired when computing GED between graph 7 and graph 23.
# Timeout expired when computing GED between graph 7 and graph 50.
# Timeout expired when computing GED between graph 7 and graph 62.
# Timeout expired when computing GED between graph 7 and graph 64.
# Timeout expired when computing GED between graph 7 and graph 70.
# Timeout expired when computing GED between graph 7 and graph 58.
# Timeout expired when computing GED between graph 7 and graph 51.
# Timeout expired when computing GED between graph 7 and graph 84.
# Timeout expired when computing GED between graph 7 and graph 89.
# Timeout expired when computing GED between graph 7 and graph 92.
# Timeout expired when computing GED between graph 7 and graph 67.
# Timeout expired when computing GED between graph 7 and graph 100.
# Timeout expired when computing GED between graph 7 and graph 108.
# Timeout expired when computing GED between graph 7 and graph 109.
# Timeout expired when computing GED between graph 7 and graph 85.
# Timeout expired when computing GED between graph 7 and graph 90.
# Timeout expired when computing GED between graph 7 and graph 95.
# Timeout expired when computing GED between graph 7 and graph 102.
# Timeout expired when computing GED between graph 7 and graph 117.
# Timeout expired when computing GED between graph 7 and graph 120.
# Timeout expired when computing GED between graph 7 and graph 121.
# Timeout expired when computing GED between graph 7 and graph 124.
# Timeout expired when computing GED between graph 7 and graph 91.
# Timeout expired when computing GED between graph 7 and graph 103.
# Timeout expired when computing GED between graph 7 and graph 139.
# Timeout expired when computing GED between graph 7 and graph 160.
# Timeout expired when computing GED between graph 7 and graph 161.
# Timeout expired when computing GED between graph 7 and graph 165.
# Timeout expired when computing GED between graph 7 and graph 174.
# Timeout expired when computing GED between graph 7 and graph 179.
# Timeout expired when computing GED between graph 7 and graph 182.
# Timeout expired when computing GED between graph 7 and graph 186.
# Timeout expired when computing GED between graph 9 and graph 45.
# Timeout expired when computing GED between graph 9 and graph 51.
# Timeout expired when computing GED between graph 9 and graph 50.
# Timeout expired when computing GED between graph 9 and graph 67.
# Timeout expired when computing GED between graph 9 and graph 62.
# Timeout expired when computing GED between graph 9 and graph 26.
# Timeout expired when computing GED between graph 9 and graph 84.
# Timeout expired when computing GED between graph 9 and graph 89.
# Timeout expired when computing GED between graph 9 and graph 95.
# Timeout expired when computing GED between graph 9 and graph 92.
# Timeout expired when computing GED between graph 9 and graph 100.
# Timeout expired when computing GED between graph 9 and graph 103.
# Timeout expired when computing GED between graph 9 and graph 70.
# Timeout expired when computing GED between graph 9 and graph 85.
# Timeout expired when computing GED between graph 9 and graph 117.
# Timeout expired when computing GED between graph 9 and graph 109.
# Timeout expired when computing GED between graph 9 and graph 160.
# Timeout expired when computing GED between graph 9 and graph 161.
# Timeout expired when computing GED between graph 9 and graph 163.
# Timeout expired when computing GED between graph 9 and graph 165.
# Timeout expired when computing GED between graph 9 and graph 166.
# Timeout expired when computing GED between graph 9 and graph 179.
# Timeout expired when computing GED between graph 9 and graph 182.
# Timeout expired when computing GED between graph 10 and graph 28.
# Timeout expired when computing GED between graph 10 and graph 31.
# Timeout expired when computing GED between graph 10 and graph 32.
# Timeout expired when computing GED between graph 10 and graph 52.
# Timeout expired when computing GED between graph 10 and graph 62.
# Timeout expired when computing GED between graph 10 and graph 101.
# Timeout expired when computing GED between graph 10 and graph 109.
# Timeout expired when computing GED between graph 10 and graph 161.
# Timeout expired when computing GED between graph 10 and graph 170.
# Timeout expired when computing GED between graph 11 and graph 12.
# Timeout expired when computing GED between graph 11 and graph 15.
# Timeout expired when computing GED between graph 11 and graph 22.
# Timeout expired when computing GED between graph 11 and graph 28.
# Timeout expired when computing GED between graph 11 and graph 29.
# Timeout expired when computing GED between graph 11 and graph 30.
# Timeout expired when computing GED between graph 11 and graph 31.
# Timeout expired when computing GED between graph 11 and graph 32.
# Timeout expired when computing GED between graph 11 and graph 50.
# Timeout expired when computing GED between graph 11 and graph 51.
# Timeout expired when computing GED between graph 11 and graph 52.
# Timeout expired when computing GED between graph 11 and graph 53.
# Timeout expired when computing GED between graph 11 and graph 56.
# Timeout expired when computing GED between graph 11 and graph 58.
# Timeout expired when computing GED between graph 11 and graph 62.
# Timeout expired when computing GED between graph 11 and graph 73.
# Timeout expired when computing GED between graph 11 and graph 74.
# Timeout expired when computing GED between graph 11 and graph 81.
# Timeout expired when computing GED between graph 11 and graph 84.
# Timeout expired when computing GED between graph 11 and graph 85.
# Timeout expired when computing GED between graph 11 and graph 90.
# Timeout expired when computing GED between graph 11 and graph 101.
# Timeout expired when computing GED between graph 11 and graph 106.
# Timeout expired when computing GED between graph 11 and graph 109.
# Timeout expired when computing GED between graph 11 and graph 116.
# Timeout expired when computing GED between graph 11 and graph 118.
# Timeout expired when computing GED between graph 11 and graph 120.
# Timeout expired when computing GED between graph 11 and graph 136.
# Timeout expired when computing GED between graph 11 and graph 151.
# Timeout expired when computing GED between graph 11 and graph 157.
# Timeout expired when computing GED between graph 11 and graph 160.
# Timeout expired when computing GED between graph 11 and graph 161.
# Timeout expired when computing GED between graph 11 and graph 170.
# Timeout expired when computing GED between graph 11 and graph 172.
# Timeout expired when computing GED between graph 11 and graph 174.
# Timeout expired when computing GED between graph 11 and graph 178.
# Timeout expired when computing GED between graph 12 and graph 22.
# Timeout expired when computing GED between graph 12 and graph 23.
# Timeout expired when computing GED between graph 12 and graph 26.
# Timeout expired when computing GED between graph 12 and graph 45.
# Timeout expired when computing GED between graph 12 and graph 50.
# Timeout expired when computing GED between graph 12 and graph 51.
# Timeout expired when computing GED between graph 12 and graph 53.
# Timeout expired when computing GED between graph 12 and graph 56.
# Timeout expired when computing GED between graph 12 and graph 57.
# Timeout expired when computing GED between graph 12 and graph 58.
# Timeout expired when computing GED between graph 12 and graph 70.
# Timeout expired when computing GED between graph 12 and graph 89.
# Timeout expired when computing GED between graph 12 and graph 90.
# Timeout expired when computing GED between graph 12 and graph 91.
# Timeout expired when computing GED between graph 12 and graph 95.
# Timeout expired when computing GED between graph 12 and graph 101.
# Timeout expired when computing GED between graph 12 and graph 103.
# Timeout expired when computing GED between graph 12 and graph 105.
# Timeout expired when computing GED between graph 12 and graph 108.
# Timeout expired when computing GED between graph 12 and graph 109.
# Timeout expired when computing GED between graph 12 and graph 116.
# Timeout expired when computing GED between graph 12 and graph 118.
# Timeout expired when computing GED between graph 12 and graph 126.
# Timeout expired when computing GED between graph 12 and graph 132.
# Timeout expired when computing GED between graph 12 and graph 135.
# Timeout expired when computing GED between graph 12 and graph 141.
# Timeout expired when computing GED between graph 12 and graph 156.
# Timeout expired when computing GED between graph 12 and graph 158.
# Timeout expired when computing GED between graph 12 and graph 160.
# Timeout expired when computing GED between graph 12 and graph 161.
# Timeout expired when computing GED between graph 12 and graph 165.
# Timeout expired when computing GED between graph 12 and graph 170.
# Timeout expired when computing GED between graph 12 and graph 172.
# Timeout expired when computing GED between graph 12 and graph 179.
# Timeout expired when computing GED between graph 13 and graph 62.
# Timeout expired when computing GED between graph 14 and graph 28.
# Timeout expired when computing GED between graph 14 and graph 32.
# Timeout expired when computing GED between graph 14 and graph 22.
# Timeout expired when computing GED between graph 14 and graph 58.
# Timeout expired when computing GED between graph 14 and graph 62.
# Timeout expired when computing GED between graph 14 and graph 73.
# Timeout expired when computing GED between graph 14 and graph 81.
# Timeout expired when computing GED between graph 14 and graph 84.
# Timeout expired when computing GED between graph 14 and graph 29.
# Timeout expired when computing GED between graph 14 and graph 101.
# Timeout expired when computing GED between graph 14 and graph 106.
# Timeout expired when computing GED between graph 14 and graph 109.
# Timeout expired when computing GED between graph 14 and graph 85.
# Timeout expired when computing GED between graph 14 and graph 120.
# Timeout expired when computing GED between graph 14 and graph 31.
# Timeout expired when computing GED between graph 14 and graph 151.
# Timeout expired when computing GED between graph 14 and graph 161.
# Timeout expired when computing GED between graph 14 and graph 170.
# Timeout expired when computing GED between graph 14 and graph 174.
# Timeout expired when computing GED between graph 15 and graph 22.
# Timeout expired when computing GED between graph 15 and graph 23.
# Timeout expired when computing GED between graph 15 and graph 26.
# Timeout expired when computing GED between graph 15 and graph 45.
# Timeout expired when computing GED between graph 15 and graph 46.
# Timeout expired when computing GED between graph 15 and graph 50.
# Timeout expired when computing GED between graph 15 and graph 51.
# Timeout expired when computing GED between graph 15 and graph 53.
# Timeout expired when computing GED between graph 15 and graph 55.
# Timeout expired when computing GED between graph 15 and graph 56.
# Timeout expired when computing GED between graph 15 and graph 57.
# Timeout expired when computing GED between graph 15 and graph 58.
# Timeout expired when computing GED between graph 15 and graph 67.
# Timeout expired when computing GED between graph 15 and graph 70.
# Timeout expired when computing GED between graph 15 and graph 78.
# Timeout expired when computing GED between graph 15 and graph 84.
# Timeout expired when computing GED between graph 15 and graph 85.
# Timeout expired when computing GED between graph 15 and graph 89.
# Timeout expired when computing GED between graph 15 and graph 90.
# Timeout expired when computing GED between graph 15 and graph 91.
# Timeout expired when computing GED between graph 15 and graph 95.
# Timeout expired when computing GED between graph 15 and graph 101.
# Timeout expired when computing GED between graph 15 and graph 102.
# Timeout expired when computing GED between graph 15 and graph 103.
# Timeout expired when computing GED between graph 15 and graph 108.
# Timeout expired when computing GED between graph 15 and graph 109.
# Timeout expired when computing GED between graph 15 and graph 116.
# Timeout expired when computing GED between graph 15 and graph 117.
# Timeout expired when computing GED between graph 15 and graph 120.
# Timeout expired when computing GED between graph 15 and graph 121.
# Timeout expired when computing GED between graph 15 and graph 124.
# Timeout expired when computing GED between graph 15 and graph 126.
# Timeout expired when computing GED between graph 15 and graph 132.
# Timeout expired when computing GED between graph 15 and graph 133.
# Timeout expired when computing GED between graph 15 and graph 135.
# Timeout expired when computing GED between graph 15 and graph 141.
# Timeout expired when computing GED between graph 15 and graph 148.
# Timeout expired when computing GED between graph 15 and graph 156.
# Timeout expired when computing GED between graph 15 and graph 158.
# Timeout expired when computing GED between graph 15 and graph 159.
# Timeout expired when computing GED between graph 15 and graph 160.
# Timeout expired when computing GED between graph 15 and graph 161.
# Timeout expired when computing GED between graph 15 and graph 162.
# Timeout expired when computing GED between graph 15 and graph 165.
# Timeout expired when computing GED between graph 15 and graph 170.
# Timeout expired when computing GED between graph 15 and graph 172.
# Timeout expired when computing GED between graph 15 and graph 174.
# Timeout expired when computing GED between graph 15 and graph 179.
# Timeout expired when computing GED between graph 16 and graph 31.
# Timeout expired when computing GED between graph 16 and graph 32.
# Timeout expired when computing GED between graph 16 and graph 62.
# Timeout expired when computing GED between graph 16 and graph 74.
# Timeout expired when computing GED between graph 16 and graph 130.
# Timeout expired when computing GED between graph 16 and graph 161.
# Timeout expired when computing GED between graph 16 and graph 170.
# Timeout expired when computing GED between graph 16 and graph 178.
# Timeout expired when computing GED between graph 17 and graph 22.
# Timeout expired when computing GED between graph 17 and graph 23.
# Timeout expired when computing GED between graph 17 and graph 46.
# Timeout expired when computing GED between graph 17 and graph 57.
# Timeout expired when computing GED between graph 17 and graph 62.
# Timeout expired when computing GED between graph 17 and graph 70.
# Timeout expired when computing GED between graph 17 and graph 108.
# Timeout expired when computing GED between graph 17 and graph 109.
# Timeout expired when computing GED between graph 17 and graph 133.
# Timeout expired when computing GED between graph 17 and graph 161.
# Timeout expired when computing GED between graph 17 and graph 162.
# Timeout expired when computing GED between graph 17 and graph 170.
# Timeout expired when computing GED between graph 19 and graph 62.
# Timeout expired when computing GED between graph 19 and graph 57.
# Timeout expired when computing GED between graph 19 and graph 45.
# Timeout expired when computing GED between graph 19 and graph 70.
# Timeout expired when computing GED between graph 19 and graph 50.
# Timeout expired when computing GED between graph 19 and graph 89.
# Timeout expired when computing GED between graph 19 and graph 84.
# Timeout expired when computing GED between graph 19 and graph 26.
# Timeout expired when computing GED between graph 19 and graph 95.
# Timeout expired when computing GED between graph 19 and graph 51.
# Timeout expired when computing GED between graph 19 and graph 67.
# Timeout expired when computing GED between graph 19 and graph 103.
# Timeout expired when computing GED between graph 19 and graph 90.
# Timeout expired when computing GED between graph 19 and graph 85.
# Timeout expired when computing GED between graph 19 and graph 117.
# Timeout expired when computing GED between graph 19 and graph 100.
# Timeout expired when computing GED between graph 19 and graph 92.
# Timeout expired when computing GED between graph 19 and graph 166.
# Timeout expired when computing GED between graph 19 and graph 160.
# Timeout expired when computing GED between graph 19 and graph 182.
# Timeout expired when computing GED between graph 20 and graph 62.
# Timeout expired when computing GED between graph 20 and graph 84.
# Timeout expired when computing GED between graph 20 and graph 85.
# Timeout expired when computing GED between graph 19 and graph 165.
# Timeout expired when computing GED between graph 20 and graph 159.
# Timeout expired when computing GED between graph 21 and graph 26.
# Timeout expired when computing GED between graph 21 and graph 45.
# Timeout expired when computing GED between graph 21 and graph 50.
# Timeout expired when computing GED between graph 21 and graph 51.
# Timeout expired when computing GED between graph 21 and graph 62.
# Timeout expired when computing GED between graph 21 and graph 67.
# Timeout expired when computing GED between graph 21 and graph 70.
# Timeout expired when computing GED between graph 21 and graph 85.
# Timeout expired when computing GED between graph 21 and graph 95.
# Timeout expired when computing GED between graph 21 and graph 117.
# Timeout expired when computing GED between graph 21 and graph 160.
# Timeout expired when computing GED between graph 22 and graph 23.
# Timeout expired when computing GED between graph 22 and graph 25.
# Timeout expired when computing GED between graph 22 and graph 30.
# Timeout expired when computing GED between graph 22 and graph 46.
# Timeout expired when computing GED between graph 22 and graph 48.
# Timeout expired when computing GED between graph 22 and graph 52.
# Timeout expired when computing GED between graph 22 and graph 56.
# Timeout expired when computing GED between graph 22 and graph 53.
# Timeout expired when computing GED between graph 22 and graph 63.
# Timeout expired when computing GED between graph 22 and graph 57.
# Timeout expired when computing GED between graph 22 and graph 64.
# Timeout expired when computing GED between graph 22 and graph 66.
# Timeout expired when computing GED between graph 22 and graph 68.
# Timeout expired when computing GED between graph 22 and graph 74.
# Timeout expired when computing GED between graph 22 and graph 76.
# Timeout expired when computing GED between graph 22 and graph 79.
# Timeout expired when computing GED between graph 22 and graph 90.
# Timeout expired when computing GED between graph 22 and graph 91.
# Timeout expired when computing GED between graph 22 and graph 81.
# Timeout expired when computing GED between graph 22 and graph 95.
# Timeout expired when computing GED between graph 22 and graph 101.
# Timeout expired when computing GED between graph 22 and graph 102.
# Timeout expired when computing GED between graph 22 and graph 105.
# Timeout expired when computing GED between graph 22 and graph 108.
# Timeout expired when computing GED between graph 22 and graph 109.
# Timeout expired when computing GED between graph 22 and graph 112.
# Timeout expired when computing GED between graph 22 and graph 116.
# Timeout expired when computing GED between graph 22 and graph 118.
# Timeout expired when computing GED between graph 22 and graph 120.
# Timeout expired when computing GED between graph 22 and graph 124.
# Timeout expired when computing GED between graph 22 and graph 126.
# Timeout expired when computing GED between graph 22 and graph 128.
# Timeout expired when computing GED between graph 22 and graph 132.
# Timeout expired when computing GED between graph 22 and graph 133.
# Timeout expired when computing GED between graph 22 and graph 135.
# Timeout expired when computing GED between graph 22 and graph 136.
# Timeout expired when computing GED between graph 22 and graph 141.
# Timeout expired when computing GED between graph 22 and graph 145.
# Timeout expired when computing GED between graph 22 and graph 148.
# Timeout expired when computing GED between graph 22 and graph 151.
# Timeout expired when computing GED between graph 22 and graph 154.
# Timeout expired when computing GED between graph 22 and graph 156.
# Timeout expired when computing GED between graph 22 and graph 157.
# Timeout expired when computing GED between graph 22 and graph 158.
# Timeout expired when computing GED between graph 22 and graph 159.
# Timeout expired when computing GED between graph 22 and graph 161.
# Timeout expired when computing GED between graph 22 and graph 162.
# Timeout expired when computing GED between graph 22 and graph 163.
# Timeout expired when computing GED between graph 22 and graph 164.
# Timeout expired when computing GED between graph 22 and graph 166.
# Timeout expired when computing GED between graph 22 and graph 168.
# Timeout expired when computing GED between graph 22 and graph 170.
# Timeout expired when computing GED between graph 22 and graph 172.
# Timeout expired when computing GED between graph 22 and graph 173.
# Timeout expired when computing GED between graph 22 and graph 174.
# Timeout expired when computing GED between graph 22 and graph 178.
# Timeout expired when computing GED between graph 22 and graph 179.
# Timeout expired when computing GED between graph 22 and graph 182.
# Timeout expired when computing GED between graph 22 and graph 183.
# Timeout expired when computing GED between graph 23 and graph 25.
# Timeout expired when computing GED between graph 23 and graph 28.
# Timeout expired when computing GED between graph 23 and graph 29.
# Timeout expired when computing GED between graph 23 and graph 30.
# Timeout expired when computing GED between graph 23 and graph 31.
# Timeout expired when computing GED between graph 23 and graph 32.
# Timeout expired when computing GED between graph 23 and graph 45.
# Timeout expired when computing GED between graph 23 and graph 46.
# Timeout expired when computing GED between graph 23 and graph 48.
# Timeout expired when computing GED between graph 23 and graph 50.
# Timeout expired when computing GED between graph 23 and graph 52.
# Timeout expired when computing GED between graph 23 and graph 53.
# Timeout expired when computing GED between graph 23 and graph 56.
# Timeout expired when computing GED between graph 23 and graph 57.
# Timeout expired when computing GED between graph 23 and graph 58.
# Timeout expired when computing GED between graph 23 and graph 59.
# Timeout expired when computing GED between graph 23 and graph 61.
# Timeout expired when computing GED between graph 23 and graph 62.
# Timeout expired when computing GED between graph 23 and graph 63.
# Timeout expired when computing GED between graph 23 and graph 66.
# Timeout expired when computing GED between graph 23 and graph 68.
# Timeout expired when computing GED between graph 23 and graph 69.
# Timeout expired when computing GED between graph 23 and graph 70.
# Timeout expired when computing GED between graph 23 and graph 73.
# Timeout expired when computing GED between graph 23 and graph 74.
# Timeout expired when computing GED between graph 23 and graph 79.
# Timeout expired when computing GED between graph 23 and graph 81.
# Timeout expired when computing GED between graph 23 and graph 84.
# Timeout expired when computing GED between graph 23 and graph 85.
# Timeout expired when computing GED between graph 23 and graph 86.
# Timeout expired when computing GED between graph 23 and graph 90.
# Timeout expired when computing GED between graph 23 and graph 94.
# Timeout expired when computing GED between graph 23 and graph 95.
# Timeout expired when computing GED between graph 23 and graph 96.
# Timeout expired when computing GED between graph 23 and graph 101.
# Timeout expired when computing GED between graph 23 and graph 106.
# Timeout expired when computing GED between graph 23 and graph 109.
# Timeout expired when computing GED between graph 23 and graph 111.
# Timeout expired when computing GED between graph 23 and graph 112.
# Timeout expired when computing GED between graph 23 and graph 113.
# Timeout expired when computing GED between graph 23 and graph 114.
# Timeout expired when computing GED between graph 23 and graph 116.
# Timeout expired when computing GED between graph 23 and graph 117.
# Timeout expired when computing GED between graph 23 and graph 118.
# Timeout expired when computing GED between graph 23 and graph 120.
# Timeout expired when computing GED between graph 23 and graph 121.
# Timeout expired when computing GED between graph 23 and graph 122.
# Timeout expired when computing GED between graph 23 and graph 126.
# Timeout expired when computing GED between graph 23 and graph 127.
# Timeout expired when computing GED between graph 23 and graph 128.
# Timeout expired when computing GED between graph 23 and graph 132.
# Timeout expired when computing GED between graph 23 and graph 133.
# Timeout expired when computing GED between graph 23 and graph 134.
# Timeout expired when computing GED between graph 23 and graph 136.
# Timeout expired when computing GED between graph 23 and graph 139.
# Timeout expired when computing GED between graph 23 and graph 141.
# Timeout expired when computing GED between graph 23 and graph 145.
# Timeout expired when computing GED between graph 23 and graph 147.
# Timeout expired when computing GED between graph 23 and graph 148.
# Timeout expired when computing GED between graph 23 and graph 149.
# Timeout expired when computing GED between graph 23 and graph 151.
# Timeout expired when computing GED between graph 23 and graph 152.
# Timeout expired when computing GED between graph 23 and graph 155.
# Timeout expired when computing GED between graph 23 and graph 157.
# Timeout expired when computing GED between graph 23 and graph 158.
# Timeout expired when computing GED between graph 23 and graph 159.
# Timeout expired when computing GED between graph 23 and graph 161.
# Timeout expired when computing GED between graph 23 and graph 162.
# Timeout expired when computing GED between graph 23 and graph 163.
# Timeout expired when computing GED between graph 23 and graph 164.
# Timeout expired when computing GED between graph 23 and graph 166.
# Timeout expired when computing GED between graph 23 and graph 168.
# Timeout expired when computing GED between graph 23 and graph 170.
# Timeout expired when computing GED between graph 23 and graph 172.
# Timeout expired when computing GED between graph 23 and graph 173.
# Timeout expired when computing GED between graph 23 and graph 174.
# Timeout expired when computing GED between graph 23 and graph 175.
# Timeout expired when computing GED between graph 23 and graph 178.
# Timeout expired when computing GED between graph 23 and graph 182.
# Timeout expired when computing GED between graph 23 and graph 183.
# Timeout expired when computing GED between graph 23 and graph 185.
# Timeout expired when computing GED between graph 24 and graph 26.
# Timeout expired when computing GED between graph 24 and graph 45.
# Timeout expired when computing GED between graph 24 and graph 50.
# Timeout expired when computing GED between graph 24 and graph 51.
# Timeout expired when computing GED between graph 24 and graph 62.
# Timeout expired when computing GED between graph 24 and graph 67.
# Timeout expired when computing GED between graph 24 and graph 70.
# Timeout expired when computing GED between graph 24 and graph 85.
# Timeout expired when computing GED between graph 24 and graph 95.
# Timeout expired when computing GED between graph 24 and graph 117.
# Timeout expired when computing GED between graph 24 and graph 160.
# Timeout expired when computing GED between graph 25 and graph 29.
# Timeout expired when computing GED between graph 25 and graph 32.
# Timeout expired when computing GED between graph 25 and graph 46.
# Timeout expired when computing GED between graph 25 and graph 62.
# Timeout expired when computing GED between graph 25 and graph 73.
# Timeout expired when computing GED between graph 25 and graph 84.
# Timeout expired when computing GED between graph 25 and graph 85.
# Timeout expired when computing GED between graph 25 and graph 108.
# Timeout expired when computing GED between graph 25 and graph 132.
# Timeout expired when computing GED between graph 25 and graph 133.
# Timeout expired when computing GED between graph 25 and graph 162.
# Timeout expired when computing GED between graph 25 and graph 174.
# Timeout expired when computing GED between graph 25 and graph 178.
# Timeout expired when computing GED between graph 25 and graph 179.
# Timeout expired when computing GED between graph 26 and graph 27.
# Timeout expired when computing GED between graph 26 and graph 28.
# Timeout expired when computing GED between graph 26 and graph 29.
# Timeout expired when computing GED between graph 26 and graph 30.
# Timeout expired when computing GED between graph 26 and graph 31.
# Timeout expired when computing GED between graph 26 and graph 32.
# Timeout expired when computing GED between graph 26 and graph 34.
# Timeout expired when computing GED between graph 26 and graph 40.
# Timeout expired when computing GED between graph 26 and graph 42.
# Timeout expired when computing GED between graph 26 and graph 50.
# Timeout expired when computing GED between graph 26 and graph 51.
# Timeout expired when computing GED between graph 26 and graph 52.
# Timeout expired when computing GED between graph 26 and graph 56.
# Timeout expired when computing GED between graph 26 and graph 60.
# Timeout expired when computing GED between graph 26 and graph 62.
# Timeout expired when computing GED between graph 26 and graph 66.
# Timeout expired when computing GED between graph 26 and graph 68.
# Timeout expired when computing GED between graph 26 and graph 70.
# Timeout expired when computing GED between graph 26 and graph 74.
# Timeout expired when computing GED between graph 26 and graph 79.
# Timeout expired when computing GED between graph 26 and graph 81.
# Timeout expired when computing GED between graph 26 and graph 84.
# Timeout expired when computing GED between graph 26 and graph 96.
# Timeout expired when computing GED between graph 26 and graph 101.
# Timeout expired when computing GED between graph 26 and graph 106.
# Timeout expired when computing GED between graph 26 and graph 108.
# Timeout expired when computing GED between graph 26 and graph 109.
# Timeout expired when computing GED between graph 26 and graph 120.
# Timeout expired when computing GED between graph 26 and graph 132.
# Timeout expired when computing GED between graph 26 and graph 136.
# Timeout expired when computing GED between graph 26 and graph 139.
# Timeout expired when computing GED between graph 26 and graph 141.
# Timeout expired when computing GED between graph 26 and graph 145.
# Timeout expired when computing GED between graph 26 and graph 148.
# Timeout expired when computing GED between graph 26 and graph 151.
# Timeout expired when computing GED between graph 26 and graph 157.
# Timeout expired when computing GED between graph 26 and graph 159.
# Timeout expired when computing GED between graph 26 and graph 160.
# Timeout expired when computing GED between graph 26 and graph 161.
# Timeout expired when computing GED between graph 26 and graph 164.
# Timeout expired when computing GED between graph 26 and graph 170.
# Timeout expired when computing GED between graph 26 and graph 174.
# Timeout expired when computing GED between graph 26 and graph 183.
# Timeout expired when computing GED between graph 27 and graph 45.
# Timeout expired when computing GED between graph 27 and graph 50.
# Timeout expired when computing GED between graph 27 and graph 51.
# Timeout expired when computing GED between graph 27 and graph 62.
# Timeout expired when computing GED between graph 27 and graph 67.
# Timeout expired when computing GED between graph 27 and graph 70.
# Timeout expired when computing GED between graph 27 and graph 85.
# Timeout expired when computing GED between graph 27 and graph 95.
# Timeout expired when computing GED between graph 27 and graph 117.
# Timeout expired when computing GED between graph 27 and graph 160.
# Timeout expired when computing GED between graph 28 and graph 29.
# Timeout expired when computing GED between graph 28 and graph 45.
# Timeout expired when computing GED between graph 28 and graph 51.
# Timeout expired when computing GED between graph 28 and graph 53.
# Timeout expired when computing GED between graph 28 and graph 55.
# Timeout expired when computing GED between graph 28 and graph 57.
# Timeout expired when computing GED between graph 28 and graph 50.
# Timeout expired when computing GED between graph 28 and graph 62.
# Timeout expired when computing GED between graph 28 and graph 58.
# Timeout expired when computing GED between graph 28 and graph 67.
# Timeout expired when computing GED between graph 28 and graph 70.
# Timeout expired when computing GED between graph 28 and graph 66.
# Timeout expired when computing GED between graph 28 and graph 73.
# Timeout expired when computing GED between graph 28 and graph 78.
# Timeout expired when computing GED between graph 28 and graph 81.
# Timeout expired when computing GED between graph 28 and graph 84.
# Timeout expired when computing GED between graph 28 and graph 85.
# Timeout expired when computing GED between graph 28 and graph 89.
# Timeout expired when computing GED between graph 28 and graph 91.
# Timeout expired when computing GED between graph 28 and graph 92.
# Timeout expired when computing GED between graph 28 and graph 93.
# Timeout expired when computing GED between graph 28 and graph 94.
# Timeout expired when computing GED between graph 28 and graph 95.
# Timeout expired when computing GED between graph 28 and graph 90.
# Timeout expired when computing GED between graph 28 and graph 100.
# Timeout expired when computing GED between graph 28 and graph 103.
# Timeout expired when computing GED between graph 28 and graph 105.
# Timeout expired when computing GED between graph 28 and graph 106.
# Timeout expired when computing GED between graph 28 and graph 108.
# Timeout expired when computing GED between graph 28 and graph 117.
# Timeout expired when computing GED between graph 28 and graph 120.
# Timeout expired when computing GED between graph 28 and graph 121.
# Timeout expired when computing GED between graph 28 and graph 130.
# Timeout expired when computing GED between graph 28 and graph 132.
# Timeout expired when computing GED between graph 28 and graph 135.
# Timeout expired when computing GED between graph 28 and graph 141.
# Timeout expired when computing GED between graph 28 and graph 156.
# Timeout expired when computing GED between graph 28 and graph 158.
# Timeout expired when computing GED between graph 28 and graph 160.
# Timeout expired when computing GED between graph 28 and graph 161.
# Timeout expired when computing GED between graph 28 and graph 165.
# Timeout expired when computing GED between graph 28 and graph 166.
# Timeout expired when computing GED between graph 28 and graph 169.
# Timeout expired when computing GED between graph 28 and graph 174.
# Timeout expired when computing GED between graph 28 and graph 179.
# Timeout expired when computing GED between graph 28 and graph 182.
# Timeout expired when computing GED between graph 29 and graph 30.
# Timeout expired when computing GED between graph 29 and graph 31.
# Timeout expired when computing GED between graph 29 and graph 42.
# Timeout expired when computing GED between graph 29 and graph 46.
# Timeout expired when computing GED between graph 29 and graph 50.
# Timeout expired when computing GED between graph 29 and graph 51.
# Timeout expired when computing GED between graph 29 and graph 52.
# Timeout expired when computing GED between graph 29 and graph 56.
# Timeout expired when computing GED between graph 29 and graph 57.
# Timeout expired when computing GED between graph 29 and graph 59.
# Timeout expired when computing GED between graph 29 and graph 61.
# Timeout expired when computing GED between graph 29 and graph 66.
# Timeout expired when computing GED between graph 29 and graph 68.
# Timeout expired when computing GED between graph 29 and graph 70.
# Timeout expired when computing GED between graph 29 and graph 74.
# Timeout expired when computing GED between graph 29 and graph 79.
# Timeout expired when computing GED between graph 29 and graph 81.
# Timeout expired when computing GED between graph 29 and graph 90.
# Timeout expired when computing GED between graph 29 and graph 91.
# Timeout expired when computing GED between graph 29 and graph 94.
# Timeout expired when computing GED between graph 29 and graph 95.
# Timeout expired when computing GED between graph 29 and graph 101.
# Timeout expired when computing GED between graph 29 and graph 102.
# Timeout expired when computing GED between graph 29 and graph 105.
# Timeout expired when computing GED between graph 29 and graph 106.
# Timeout expired when computing GED between graph 29 and graph 108.
# Timeout expired when computing GED between graph 29 and graph 109.
# Timeout expired when computing GED between graph 29 and graph 112.
# Timeout expired when computing GED between graph 29 and graph 113.
# Timeout expired when computing GED between graph 29 and graph 116.
# Timeout expired when computing GED between graph 29 and graph 118.
# Timeout expired when computing GED between graph 29 and graph 120.
# Timeout expired when computing GED between graph 29 and graph 121.
# Timeout expired when computing GED between graph 29 and graph 122.
# Timeout expired when computing GED between graph 29 and graph 124.
# Timeout expired when computing GED between graph 29 and graph 126.
# Timeout expired when computing GED between graph 29 and graph 128.
# Timeout expired when computing GED between graph 29 and graph 132.
# Timeout expired when computing GED between graph 29 and graph 133.
# Timeout expired when computing GED between graph 29 and graph 134.
# Timeout expired when computing GED between graph 29 and graph 135.
# Timeout expired when computing GED between graph 29 and graph 139.
# Timeout expired when computing GED between graph 29 and graph 145.
# Timeout expired when computing GED between graph 29 and graph 151.
# Timeout expired when computing GED between graph 29 and graph 154.
# Timeout expired when computing GED between graph 29 and graph 156.
# Timeout expired when computing GED between graph 29 and graph 157.
# Timeout expired when computing GED between graph 29 and graph 158.
# Timeout expired when computing GED between graph 29 and graph 159.
# Timeout expired when computing GED between graph 29 and graph 160.
# Timeout expired when computing GED between graph 29 and graph 161.
# Timeout expired when computing GED between graph 29 and graph 162.
# Timeout expired when computing GED between graph 29 and graph 163.
# Timeout expired when computing GED between graph 29 and graph 164.
# Timeout expired when computing GED between graph 29 and graph 166.
# Timeout expired when computing GED between graph 29 and graph 168.
# Timeout expired when computing GED between graph 29 and graph 170.
# Timeout expired when computing GED between graph 29 and graph 172.
# Timeout expired when computing GED between graph 29 and graph 174.
# Timeout expired when computing GED between graph 29 and graph 178.
# Timeout expired when computing GED between graph 29 and graph 179.
# Timeout expired when computing GED between graph 29 and graph 182.
# Timeout expired when computing GED between graph 30 and graph 31.
# Timeout expired when computing GED between graph 30 and graph 45.
# ...
# Timeout expired when computing GED between graph 135 and graph 178.
# Timeout expired when computing GED between graph 135 and graph 179.
# Timeout expired when computing GED between graph 135 and graph 183.
# Timeout expired when computing GED between graph 135 and graph 186.
# Timeout expired when computing GED between graph 136 and graph 141.
# Timeout expired when computing GED between graph 136 and graph 145.
# Timeout expired when computing GED between graph 136 and graph 148.
# Timeout expired when computing GED between graph 136 and graph 156.
# Timeout expired when computing GED between graph 136 and graph 158.
# Timeout expired when computing GED between graph 136 and graph 160.
# Timeout expired when computing GED between graph 136 and graph 165.
# Timeout expired when computing GED between graph 136 and graph 170.
# Timeout expired when computing GED between graph 136 and graph 174.
# Timeout expired when computing GED between graph 136 and graph 179.
# Timeout expired when computing GED between graph 137 and graph 161.
# Timeout expired when computing GED between graph 137 and graph 172.
# Timeout expired when computing GED between graph 137 and graph 178.
# Timeout expired when computing GED between graph 139 and graph 151.
# Timeout expired when computing GED between graph 139 and graph 157.
# Timeout expired when computing GED between graph 139 and graph 160.
# Timeout expired when computing GED between graph 139 and graph 161.
# Timeout expired when computing GED between graph 139 and graph 162.
# Timeout expired when computing GED between graph 139 and graph 174.
# Timeout expired when computing GED between graph 139 and graph 178.
# Timeout expired when computing GED between graph 139 and graph 179.
# Timeout expired when computing GED between graph 139 and graph 186.
# Timeout expired when computing GED between graph 140 and graph 170.
# Timeout expired when computing GED between graph 141 and graph 147.
# Timeout expired when computing GED between graph 141 and graph 151.
# Timeout expired when computing GED between graph 141 and graph 152.
# Timeout expired when computing GED between graph 141 and graph 160.
# Timeout expired when computing GED between graph 141 and graph 161.
# Timeout expired when computing GED between graph 141 and graph 162.
# Timeout expired when computing GED between graph 141 and graph 163.
# Timeout expired when computing GED between graph 141 and graph 166.
# Timeout expired when computing GED between graph 141 and graph 165.
# Timeout expired when computing GED between graph 141 and graph 168.
# Timeout expired when computing GED between graph 141 and graph 170.
# Timeout expired when computing GED between graph 141 and graph 172.
# Timeout expired when computing GED between graph 141 and graph 173.
# Timeout expired when computing GED between graph 141 and graph 178.
# Timeout expired when computing GED between graph 141 and graph 179.
# Timeout expired when computing GED between graph 141 and graph 182.
# Timeout expired when computing GED between graph 141 and graph 183.
# Timeout expired when computing GED between graph 145 and graph 151.
# Timeout expired when computing GED between graph 145 and graph 163.
# Timeout expired when computing GED between graph 145 and graph 173.
# Timeout expired when computing GED between graph 145 and graph 160.
# Timeout expired when computing GED between graph 145 and graph 179.
# Timeout expired when computing GED between graph 145 and graph 183.
# Timeout expired when computing GED between graph 145 and graph 174.
# Timeout expired when computing GED between graph 145 and graph 182.
# Timeout expired when computing GED between graph 145 and graph 165.
# Timeout expired when computing GED between graph 146 and graph 172.
# Timeout expired when computing GED between graph 146 and graph 161.
# Timeout expired when computing GED between graph 146 and graph 178.
# Timeout expired when computing GED between graph 145 and graph 166.
# Timeout expired when computing GED between graph 147 and graph 160.
# Timeout expired when computing GED between graph 147 and graph 161.
# Timeout expired when computing GED between graph 147 and graph 162.
# Timeout expired when computing GED between graph 147 and graph 170.
# Timeout expired when computing GED between graph 147 and graph 174.
# Timeout expired when computing GED between graph 147 and graph 178.
# Timeout expired when computing GED between graph 147 and graph 179.
# Timeout expired when computing GED between graph 148 and graph 151.
# Timeout expired when computing GED between graph 148 and graph 152.
# Timeout expired when computing GED between graph 148 and graph 156.
# Timeout expired when computing GED between graph 148 and graph 161.
# Timeout expired when computing GED between graph 148 and graph 163.
# Timeout expired when computing GED between graph 148 and graph 165.
# Timeout expired when computing GED between graph 148 and graph 168.
# Timeout expired when computing GED between graph 148 and graph 172.
# Timeout expired when computing GED between graph 148 and graph 173.
# Timeout expired when computing GED between graph 148 and graph 179.
# Timeout expired when computing GED between graph 148 and graph 183.
# Timeout expired when computing GED between graph 149 and graph 160.
# Timeout expired when computing GED between graph 149 and graph 179.
# Timeout expired when computing GED between graph 151 and graph 152.
# Timeout expired when computing GED between graph 151 and graph 156.
# Timeout expired when computing GED between graph 151 and graph 158.
# Timeout expired when computing GED between graph 151 and graph 160.
# Timeout expired when computing GED between graph 151 and graph 161.
# Timeout expired when computing GED between graph 151 and graph 163.
# Timeout expired when computing GED between graph 151 and graph 165.
# Timeout expired when computing GED between graph 151 and graph 166.
# Timeout expired when computing GED between graph 151 and graph 169.
# Timeout expired when computing GED between graph 151 and graph 170.
# Timeout expired when computing GED between graph 151 and graph 172.
# Timeout expired when computing GED between graph 151 and graph 179.
# Timeout expired when computing GED between graph 151 and graph 182.
# Timeout expired when computing GED between graph 152 and graph 160.
# Timeout expired when computing GED between graph 152 and graph 161.
# Timeout expired when computing GED between graph 152 and graph 162.
# Timeout expired when computing GED between graph 152 and graph 170.
# Timeout expired when computing GED between graph 152 and graph 172.
# Timeout expired when computing GED between graph 152 and graph 174.
# Timeout expired when computing GED between graph 152 and graph 176.
# Timeout expired when computing GED between graph 152 and graph 178.
# Timeout expired when computing GED between graph 152 and graph 179.
# Timeout expired when computing GED between graph 152 and graph 186.
# Timeout expired when computing GED between graph 153 and graph 161.
# Timeout expired when computing GED between graph 153 and graph 172.
# Timeout expired when computing GED between graph 153 and graph 179.
# Timeout expired when computing GED between graph 153 and graph 178.
# Timeout expired when computing GED between graph 154 and graph 162.
# Timeout expired when computing GED between graph 154 and graph 174.
# Timeout expired when computing GED between graph 155 and graph 160.
# Timeout expired when computing GED between graph 155 and graph 179.
# Timeout expired when computing GED between graph 156 and graph 157.
# Timeout expired when computing GED between graph 156 and graph 161.
# Timeout expired when computing GED between graph 156 and graph 162.
# Timeout expired when computing GED between graph 156 and graph 170.
# Timeout expired when computing GED between graph 156 and graph 172.
# Timeout expired when computing GED between graph 156 and graph 173.
# Timeout expired when computing GED between graph 156 and graph 174.
# Timeout expired when computing GED between graph 156 and graph 178.
# Timeout expired when computing GED between graph 156 and graph 186.
# Timeout expired when computing GED between graph 157 and graph 160.
# Timeout expired when computing GED between graph 157 and graph 161.
# Timeout expired when computing GED between graph 157 and graph 165.
# Timeout expired when computing GED between graph 157 and graph 168.
# Timeout expired when computing GED between graph 157 and graph 174.
# Timeout expired when computing GED between graph 157 and graph 179.
# Timeout expired when computing GED between graph 157 and graph 182.
# Timeout expired when computing GED between graph 157 and graph 186.
# Timeout expired when computing GED between graph 158 and graph 160.
# Timeout expired when computing GED between graph 158 and graph 161.
# Timeout expired when computing GED between graph 158 and graph 162.
# Timeout expired when computing GED between graph 158 and graph 170.
# Timeout expired when computing GED between graph 158 and graph 173.
# Timeout expired when computing GED between graph 158 and graph 174.
# Timeout expired when computing GED between graph 158 and graph 172.
# Timeout expired when computing GED between graph 158 and graph 178.
# Timeout expired when computing GED between graph 158 and graph 183.
# Timeout expired when computing GED between graph 159 and graph 161.
# Timeout expired when computing GED between graph 159 and graph 162.
# Timeout expired when computing GED between graph 159 and graph 166.
# Timeout expired when computing GED between graph 159 and graph 170.
# Timeout expired when computing GED between graph 159 and graph 172.
# Timeout expired when computing GED between graph 159 and graph 173.
# Timeout expired when computing GED between graph 159 and graph 174.
# Timeout expired when computing GED between graph 159 and graph 178.
# Timeout expired when computing GED between graph 159 and graph 183.
# Timeout expired when computing GED between graph 159 and graph 182.
# Timeout expired when computing GED between graph 160 and graph 161.
# Timeout expired when computing GED between graph 160 and graph 162.
# Timeout expired when computing GED between graph 160 and graph 163.
# Timeout expired when computing GED between graph 160 and graph 164.
# Timeout expired when computing GED between graph 160 and graph 165.
# Timeout expired when computing GED between graph 160 and graph 168.
# Timeout expired when computing GED between graph 160 and graph 170.
# Timeout expired when computing GED between graph 160 and graph 172.
# Timeout expired when computing GED between graph 160 and graph 173.
# Timeout expired when computing GED between graph 160 and graph 174.
# Timeout expired when computing GED between graph 160 and graph 175.
# Timeout expired when computing GED between graph 160 and graph 178.Timeout expired when computing GED between graph 160 and graph 179.
#
# Timeout expired when computing GED between graph 160 and graph 182.
# Timeout expired when computing GED between graph 160 and graph 183.
# Timeout expired when computing GED between graph 160 and graph 185.
# Timeout expired when computing GED between graph 161 and graph 162.
# Timeout expired when computing GED between graph 161 and graph 163.
# Timeout expired when computing GED between graph 161 and graph 164.
# Timeout expired when computing GED between graph 161 and graph 165.
# Timeout expired when computing GED between graph 161 and graph 166.
# Timeout expired when computing GED between graph 161 and graph 169.
# Timeout expired when computing GED between graph 161 and graph 174.
# Timeout expired when computing GED between graph 161 and graph 176.
# Timeout expired when computing GED between graph 161 and graph 177.
# Timeout expired when computing GED between graph 161 and graph 178.
# Timeout expired when computing GED between graph 161 and graph 179.
# Timeout expired when computing GED between graph 161 and graph 182.
# Timeout expired when computing GED between graph 161 and graph 186.
# Timeout expired when computing GED between graph 161 and graph 187.
# Timeout expired when computing GED between graph 162 and graph 168.
# Timeout expired when computing GED between graph 162 and graph 169.
# Timeout expired when computing GED between graph 162 and graph 172.
# Timeout expired when computing GED between graph 162 and graph 174.
# Timeout expired when computing GED between graph 162 and graph 179.
# Timeout expired when computing GED between graph 162 and graph 183.
# Timeout expired when computing GED between graph 162 and graph 187.
# Timeout expired when computing GED between graph 163 and graph 170.
# Timeout expired when computing GED between graph 163 and graph 172.
# Timeout expired when computing GED between graph 163 and graph 174.
# Timeout expired when computing GED between graph 163 and graph 179.
# Timeout expired when computing GED between graph 164 and graph 165.
# Timeout expired when computing GED between graph 164 and graph 166.
# Timeout expired when computing GED between graph 164 and graph 170.
# Timeout expired when computing GED between graph 164 and graph 174.
# Timeout expired when computing GED between graph 164 and graph 179.
# Timeout expired when computing GED between graph 165 and graph 170.
# Timeout expired when computing GED between graph 165 and graph 172.
# Timeout expired when computing GED between graph 165 and graph 173.
# Timeout expired when computing GED between graph 165 and graph 174.
# Timeout expired when computing GED between graph 165 and graph 178.
# Timeout expired when computing GED between graph 165 and graph 179.
# Timeout expired when computing GED between graph 165 and graph 183.
# Timeout expired when computing GED between graph 165 and graph 186.
# Timeout expired when computing GED between graph 166 and graph 170.
# Timeout expired when computing GED between graph 166 and graph 172.
# Timeout expired when computing GED between graph 166 and graph 174.
# Timeout expired when computing GED between graph 166 and graph 179.
# Timeout expired when computing GED between graph 168 and graph 174.
# Timeout expired when computing GED between graph 168 and graph 178.
# Timeout expired when computing GED between graph 168 and graph 179.
# Timeout expired when computing GED between graph 169 and graph 170.
# Timeout expired when computing GED between graph 170 and graph 174.
# Timeout expired when computing GED between graph 170 and graph 176.
# Timeout expired when computing GED between graph 170 and graph 178.
# Timeout expired when computing GED between graph 170 and graph 179.
# Timeout expired when computing GED between graph 170 and graph 182.
# Timeout expired when computing GED between graph 170 and graph 183.
# Timeout expired when computing GED between graph 172 and graph 174.
# Timeout expired when computing GED between graph 172 and graph 179.
# Timeout expired when computing GED between graph 172 and graph 182.
# Timeout expired when computing GED between graph 172 and graph 186.
# Timeout expired when computing GED between graph 173 and graph 179.
# Timeout expired when computing GED between graph 173 and graph 184.
# Timeout expired when computing GED between graph 174 and graph 178.
# Timeout expired when computing GED between graph 174 and graph 179.
# Timeout expired when computing GED between graph 174 and graph 183.
# Timeout expired when computing GED between graph 174 and graph 182.
# Timeout expired when computing GED between graph 174 and graph 186.
# Timeout expired when computing GED between graph 175 and graph 179.
# Timeout expired when computing GED between graph 177 and graph 178.
# Timeout expired when computing GED between graph 178 and graph 179.
# Timeout expired when computing GED between graph 178 and graph 181.
# Timeout expired when computing GED between graph 178 and graph 182.
# Timeout expired when computing GED between graph 178 and graph 183.
# Timeout expired when computing GED between graph 179 and graph 182.
# Timeout expired when computing GED between graph 179 and graph 183.
# Timeout expired when computing GED between graph 179 and graph 185.
# Finished calculating exact GED distance matrix.
# [[ 0 11 11 ... 13  9  6]
#  [11  0  0 ...  4 20  9]
#  [11  0  0 ...  4 20  9]
#  ...
#  [13  4  4 ...  0 22  9]
#  [ 9 20 20 ... 22  0 13]
#  [ 6  9  9 ...  9 13  0]]
